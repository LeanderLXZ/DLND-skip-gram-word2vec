# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
text[:1000]
# Out:
# ' anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti'

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    # create embedding weight matrix here
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) 
    # use tf.nn.embedding_lookup to get the hidden layer output
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, 
                                      softmax_b, 
                                      labels, 
                                      embed,
                                      n_sampled, 
                                      n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6632 0.2470 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6149 0.2497 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5089 0.2465 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5797 0.2523 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5234 0.2281 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5332 0.2308 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5262 0.2448 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5507 0.2196 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4444 0.2479 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4860 0.2936 sec/batch
# Nearest to known: fenway, mantle, rectifiers, pcs, expellees, apes, shareholding, maga,
# Nearest to while: affricates, normalized, vcs, permeated, redding, iff, fused, botulism,
# Nearest to who: mickiewicz, runners, thatched, injera, vent, traditionally, joke, rentenmark,
# Nearest to with: csf, deem, deism, micelles, testicles, amply, mashed, raise,
# Nearest to an: maskable, colonial, searching, hiiumaa, halicarnassus, rup, lytton, mages,
# Nearest to into: tung, gt, nonconformists, teixeira, cambrian, latveria, fangio, controversies,
# Nearest to people: benvenuto, sensual, cannot, fasci, instrumental, bcd, creature, niki,
# Nearest to d: actaeon, contemptuous, suburb, platinum, swap, emphases, provisions, borrowings,
# Nearest to creation: cddb, plummet, benzoyl, treatise, carolinas, saturation, clonic, svg,
# Nearest to consists: medical, comic, rupert, climates, ile, broadband, sexiest, mishpat,
# Nearest to orthodox: eurostar, amigaone, oscillatory, densely, styrian, parades, hovercraft, willoughby,
# Nearest to governor: dredged, prompt, diphthong, yeah, snorting, lempira, invasions, vaccination,
# Nearest to writers: binders, randall, schiavo, liberalisation, rundown, maranh, readily, monotheistic,
# Nearest to rise: biasing, doubted, mari, rosie, sled, polisario, incidents, antibody,
# Nearest to paris: gai, submarines, rove, mentality, subkey, creations, atherosclerosis, reversibly,
# Nearest to heavy: condita, aleksei, humvee, bonifacio, irregularly, counterfeit, platforms, milky,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4783 0.2772 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3878 0.2558 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3159 0.2489 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2415 0.2289 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2038 0.2638 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1500 0.2365 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1062 0.2247 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0242 0.2245 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0264 0.2310 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9967 0.2245 sec/batch
# Nearest to known: mantle, rectifiers, fenway, fulfillment, communicating, exciting, six, szczecin,
# Nearest to while: affricates, iff, normalized, translated, fused, permeated, believing, produced,
# Nearest to who: traditionally, mickiewicz, indeed, joke, runners, thatched, speech, gifts,
# Nearest to with: new, deism, csf, deem, it, raise, questions, charities,
# Nearest to an: colonial, maskable, searching, rup, lytton, is, northeastern, assess,
# Nearest to into: tung, controversies, gt, omniscient, nonconformists, its, statement, represents,
# Nearest to people: cannot, sensual, instrumental, creature, benvenuto, smoothness, ranging, freeze,
# Nearest to d: actaeon, contemptuous, suburb, platinum, detected, provisions, serve, borrowings,
# Nearest to creation: treatise, cddb, maritimes, benzoyl, incised, better, plummet, saturation,
# Nearest to consists: medical, comic, climates, controls, broadband, rupert, passers, homage,
# Nearest to orthodox: eurostar, densely, defending, amigaone, a, does, fellow, iv,
# Nearest to governor: yeah, diphthong, invasions, approval, tapes, dredged, prompt, doctrinal,
# Nearest to writers: binders, randall, grateful, emerged, theology, liberalisation, tremendous, readily,
# Nearest to rise: doubted, incidents, biasing, mari, situations, ted, sled, advantages,
# Nearest to paris: submarines, gai, rove, creations, trusted, mentality, summons, reversibly,
# Nearest to heavy: milky, bonifacio, broadcaster, platforms, shifted, condita, delivering, aliases,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9349 0.2361 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9062 0.2301 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8622 0.2283 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8679 0.2295 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8221 0.2311 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7984 0.2318 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8068 0.2317 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8104 0.2314 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7601 0.2323 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7915 0.2345 sec/batch
# Nearest to known: mantle, fenway, rectifiers, fulfillment, communicating, apes, shortwave, exciting,
# Nearest to while: affricates, fused, iff, transformations, believing, permeated, narrow, sicilian,
# Nearest to who: rotations, traditionally, runners, thatched, mickiewicz, indeed, reintroduced, executor,
# Nearest to with: csf, deism, deem, raise, new, completing, charities, financially,
# Nearest to an: colonial, maskable, searching, rup, halicarnassus, frameworks, hiiumaa, illustrating,
# Nearest to into: tung, controversies, gt, omniscient, nonconformists, cambrian, giordano, ecuador,
# Nearest to people: cannot, sensual, instrumental, creature, ranging, benvenuto, freeze, smoothness,
# Nearest to d: actaeon, contemptuous, suburb, platinum, trent, endeavor, borrowings, decrypted,
# Nearest to creation: treatise, maritimes, saturation, cddb, benzoyl, better, incised, trademark,
# Nearest to consists: medical, comic, climates, rupert, broadband, controls, displayed, crescendo,
# Nearest to orthodox: eurostar, densely, defending, does, amigaone, asked, iv, a,
# Nearest to governor: approval, invasions, yeah, tapes, coalesce, snorting, doctrinal, linked,
# Nearest to writers: randall, binders, grateful, liberalisation, emerged, theology, monotheistic, readily,
# Nearest to rise: doubted, incidents, sled, mari, situations, rosie, authorities, advantages,
# Nearest to paris: gai, submarines, mentality, trusted, hampshire, rove, creations, reversibly,
# Nearest to heavy: milky, shifted, bonifacio, platforms, deeds, aliases, broadcaster, remission,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7840 0.2368 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7877 0.2307 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7173 0.2310 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7020 0.2287 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7596 0.2378 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7124 0.2322 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6931 0.2328 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7481 0.2303 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7198 0.2301 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6650 0.2303 sec/batch
# Nearest to known: mantle, fenway, fulfillment, rectifiers, soprano, apes, relinquished, maga,
# Nearest to while: affricates, sicilian, fused, believing, permeated, redding, adolph, iff,
# Nearest to who: rotations, runners, reintroduced, vent, thatched, mickiewicz, crab, traditionally,
# Nearest to with: deem, csf, deism, skewed, tampa, raise, charities, it,
# Nearest to an: colonial, maskable, halicarnassus, searching, rup, hiiumaa, frameworks, illustrating,
# Nearest to into: tung, gt, cambrian, omniscient, controversies, ecuador, nicobar, giordano,
# Nearest to people: sensual, cannot, instrumental, participants, freeze, benvenuto, egan, smoothness,
# Nearest to d: statesman, actaeon, composer, contemptuous, suburb, journalist, decrypted, trent,
# Nearest to creation: treatise, saturation, benzoyl, plummet, incised, cddb, svg, maritimes,
# Nearest to consists: medical, climates, comic, rupert, broadband, controls, glacial, crescendo,
# Nearest to orthodox: eurostar, densely, asked, toleration, amigaone, hovercraft, defending, marshland,
# Nearest to governor: approval, invasions, snorting, prompt, dredged, doctrinal, yeah, thirteenth,
# Nearest to writers: randall, grateful, liberalisation, binders, theology, monotheistic, emerged, chan,
# Nearest to rise: incidents, biasing, doubted, rosie, sled, mari, authorities, expedite,
# Nearest to paris: mentality, gai, hampshire, submarines, reversibly, trusted, pollard, summons,
# Nearest to heavy: bonifacio, shifted, platforms, milky, remission, aliases, aleksei, withdraws,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6849 0.2372 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6451 0.2310 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5994 0.2237 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6413 0.2333 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6479 0.2330 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6296 0.2315 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6180 0.1678 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5712 0.2297 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.4832 0.2315 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5019 0.2308 sec/batch
# Nearest to known: mantle, apes, rectifiers, fulfillment, fenway, nested, soprano, maga,
# Nearest to while: sicilian, fused, affricates, believing, redding, permeated, normalized, iff,
# Nearest to who: rotations, wife, crab, hopper, ensconced, pottery, runners, executor,
# Nearest to with: deem, csf, deism, skewed, glastonbury, gallons, nammu, straddles,
# Nearest to an: colonial, maskable, mileva, halicarnassus, searching, illustrating, frameworks, mages,
# Nearest to into: tung, gt, ecuador, cambrian, controversies, omniscient, gwyneth, orchards,
# Nearest to people: sensual, participants, egan, trader, instrumental, proximity, smoothness, cannot,
# Nearest to d: statesman, composer, journalist, one, singer, actaeon, six, born,
# Nearest to creation: treatise, incised, svg, saturation, benzoyl, cddb, plummet, better,
# Nearest to consists: medical, climates, controls, passers, broadband, crescendo, glacial, sexiest,
# Nearest to orthodox: eurostar, toleration, asked, densely, marshland, amigaone, hovercraft, defending,
# Nearest to governor: approval, dredged, cabinet, thirteenth, advisor, invasions, scholasticus, stroessner,
# Nearest to writers: grateful, randall, theology, liberalisation, binders, philosophers, quicksilver, chan,
# Nearest to rise: biasing, incidents, authorities, rosie, doubted, mari, sled, practices,
# Nearest to paris: mentality, hampshire, gai, pollard, creations, rove, reversibly, harz,
# Nearest to heavy: bonifacio, aliases, meatballwiki, remission, counterfeit, platforms, shifted, condita,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4893 0.2375 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4787 0.2303 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4741 0.2332 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5273 0.2302 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4856 0.2318 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4726 0.2311 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4627 0.2296 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4094 0.2123 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4555 0.2300 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4210 0.2296 sec/batch
# Nearest to known: mantle, nested, apes, fenway, fulfillment, rectifiers, maga, shareholding,
# Nearest to while: sicilian, fused, affricates, redding, secularization, permeated, normalized, ambition,
# Nearest to who: wife, rotations, crab, executor, hopper, ensconced, expressible, adrianople,
# Nearest to with: deem, csf, deism, skewed, glastonbury, amply, gallons, tampa,
# Nearest to an: maskable, colonial, halicarnassus, illustrating, searching, is, mileva, pcm,
# Nearest to into: gt, tung, controversies, cambrian, ecuador, marshes, gwyneth, orchards,
# Nearest to people: sensual, participants, trader, egan, creature, smoothness, instrumental, cannot,
# Nearest to d: statesman, composer, actaeon, journalist, suburb, decrypted, contemptuous, eroticism,
# Nearest to creation: treatise, better, saturation, carolinas, amigas, incised, plummet, cddb,
# Nearest to consists: climates, medical, glacial, passers, controls, between, sexiest, crescendo,
# Nearest to orthodox: toleration, asked, eurostar, iv, defending, confided, disuse, criticise,
# Nearest to governor: approval, cabinet, dredged, thirteenth, stroessner, scholasticus, tories, invasions,
# Nearest to writers: grateful, theology, randall, philosophers, quicksilver, binders, liberalisation, posing,
# Nearest to rise: biasing, authorities, incidents, rosie, practices, expedite, mossad, sled,
# Nearest to paris: gai, pollard, mentality, hampshire, creations, rove, trusted, reversibly,
# Nearest to heavy: bonifacio, aliases, fire, meatballwiki, remission, codebase, shifted, counterfeit,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4471 0.2359 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4050 0.2315 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.3997 0.2304 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3913 0.2305 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4204 0.2311 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4351 0.2311 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3850 0.2306 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3794 0.2501 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4037 0.2550 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3710 0.2643 sec/batch
# Nearest to known: mantle, nested, fenway, apes, maga, fulfillment, communicating, shareholding,
# Nearest to while: permeated, affricates, secularization, sicilian, fused, redding, normalized, alor,
# Nearest to who: wife, crab, hopper, indeed, executor, gifts, rotations, metered,
# Nearest to with: deem, csf, deism, skewed, gallons, mashed, amply, glastonbury,
# Nearest to an: maskable, colonial, illustrating, pcm, is, searching, mileva, halicarnassus,
# Nearest to into: gt, tung, cambrian, controversies, ecuador, orchards, omniscient, marshes,
# Nearest to people: participants, sensual, creature, egan, smoothness, trader, proximity, bcd,
# Nearest to d: statesman, actaeon, contemptuous, suburb, composer, eroticism, decrypted, une,
# Nearest to creation: treatise, better, carolinas, amigas, saturation, incised, cddb, plummet,
# Nearest to consists: climates, medical, glacial, between, passers, sexiest, orthogonality, controls,
# Nearest to orthodox: toleration, apostolic, roman, churches, constantinople, oriental, asked, iv,
# Nearest to governor: approval, cabinet, dredged, advisor, stroessner, tories, scholasticus, eritrea,
# Nearest to writers: philosophers, theology, grateful, quicksilver, randall, binders, posing, liberalisation,
# Nearest to rise: biasing, incidents, practices, authorities, rosie, sled, expedite, antibody,
# Nearest to paris: gai, pollard, hampshire, parma, mentality, creations, venona, prevenient,
# Nearest to heavy: fire, aliases, meatballwiki, bonifacio, codebase, shifted, remission, condita,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3855 0.2571 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3682 0.2609 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3671 0.2526 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3472 0.2578 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3947 0.2603 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3677 0.2588 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3807 0.2676 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3790 0.2576 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3362 0.2618 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3516 0.2577 sec/batch
# Nearest to known: mantle, fenway, europe, shareholding, nested, maga, nmda, expellees,
# Nearest to while: affricates, secularization, sicilian, permeated, redding, fused, normalized, heresiologists,
# Nearest to who: wife, crab, executor, hopper, gifts, indeed, sardar, fellow,
# Nearest to with: deem, csf, deism, gallons, wingers, mashed, skewed, rubles,
# Nearest to an: halicarnassus, maskable, colonial, frameworks, mileva, searching, is, pcm,
# Nearest to into: cambrian, gt, tung, orchards, gwyneth, vdp, jaguar, omniscient,
# Nearest to people: creature, participants, sensual, bcd, egan, cannot, smoothness, orientation,
# Nearest to d: actaeon, statesman, contemptuous, eroticism, composer, suburb, explorer, une,
# Nearest to creation: treatise, carolinas, better, svg, amigas, plummet, cddb, incised,
# Nearest to consists: climates, medical, glacial, orthogonality, summers, between, sexiest, rupert,
# Nearest to orthodox: toleration, apostolic, churches, theological, constantinople, persecuted, disuse, patriarch,
# Nearest to governor: approval, cabinet, stroessner, dredged, tories, advisor, council, eritrea,
# Nearest to writers: philosophers, theology, grateful, quicksilver, randall, deaths, binders, lash,
# Nearest to rise: incidents, authorities, biasing, sled, rosie, practices, invasion, expedite,
# Nearest to paris: pollard, gai, parma, creations, hampshire, venona, mentality, prevenient,
# Nearest to heavy: fire, aliases, meatballwiki, bonifacio, homeported, codebase, shifted, withdraws,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3459 0.2654 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2909 0.2639 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3859 0.2649 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3469 0.2599 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3898 0.2632 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2987 0.2540 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3078 0.2552 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3669 0.2629 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2416 0.2541 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2933 0.2645 sec/batch
# Nearest to known: mantle, shareholding, nmda, uga, fenway, wasps, europe, expellees,
# Nearest to while: affricates, secularization, sicilian, permeated, fused, normalized, heresiologists, terminates,
# Nearest to who: wife, hopper, executor, fellow, mickiewicz, metered, indeed, gifts,
# Nearest to with: deem, csf, deism, rubles, bremer, skewed, gallons, wingers,
# Nearest to an: halicarnassus, maskable, novellae, mileva, colonial, excel, enquirer, centered,
# Nearest to into: orchards, gt, tung, cambrian, ecuador, kilometres, jaguar, rigid,
# Nearest to people: participants, bcd, egan, trader, proximity, sensual, creature, argues,
# Nearest to d: statesman, composer, actaeon, one, contemptuous, antoine, croatian, eroticism,
# Nearest to creation: treatise, carolinas, amigas, svg, metallocenes, plummet, empiricists, better,
# Nearest to consists: climates, medical, glacial, orthogonality, between, summers, rupert, passers,
# Nearest to orthodox: toleration, apostolic, patriarch, persecuted, churches, constantinople, theological, iv,
# Nearest to governor: approval, cabinet, stroessner, dredged, tories, advisor, selects, council,
# Nearest to writers: philosophers, theology, grateful, quicksilver, alumni, deaths, essayists, xenophanes,
# Nearest to rise: incidents, sled, polisario, authorities, biasing, mossad, invasion, practices,
# Nearest to paris: parma, pollard, gai, venona, hampshire, creations, prevenient, regent,
# Nearest to heavy: fire, meatballwiki, aliases, homeported, bonifacio, codebase, uptime, ringers,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3197 0.2605 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2931 0.2590 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3375 0.1208 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2699 0.2566 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2289 0.2618 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2328 0.2616 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2232 0.2571 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2470 0.2603 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2077 0.2586 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2005 0.2627 sec/batch
# Nearest to known: mantle, shareholding, uga, europe, nmda, expellees, aegeus, apes,
# Nearest to while: sicilian, secularization, affricates, normalized, fused, permeated, resentment, terminates,
# Nearest to who: wife, indeed, fellow, executor, mickiewicz, hopper, metered, reintroduced,
# Nearest to with: deem, deism, csf, gallons, rubles, skewed, amply, wingers,
# Nearest to an: maskable, halicarnassus, novellae, mileva, colonial, centered, menlo, ep,
# Nearest to into: orchards, gt, kilometres, tung, cambrian, ecuador, plains, its,
# Nearest to people: participants, egan, trader, argues, proximity, microarchitecture, bcd, sensual,
# Nearest to d: statesman, actaeon, composer, explorer, contemptuous, croatian, eroticism, henri,
# Nearest to creation: treatise, carolinas, amigas, plummet, better, svg, empiricists, cddb,
# Nearest to consists: climates, glacial, medical, orthogonality, summers, passers, predominate, between,
# Nearest to orthodox: toleration, apostolic, patriarch, persecuted, oriental, theological, constantinople, iv,
# Nearest to governor: approval, dredged, cabinet, stroessner, advisor, selects, tories, scholasticus,
# Nearest to writers: philosophers, theology, quicksilver, grateful, essayists, alumni, deaths, xenophanes,
# Nearest to rise: polisario, incidents, sled, biasing, authorities, foote, heydrich, polluted,
# Nearest to paris: pollard, gai, parma, creations, venona, hampshire, tauris, prevenient,
# Nearest to heavy: fire, aliases, homeported, meatballwiki, codebase, bonifacio, ennio, ringers,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2527 0.2648 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1989 0.2593 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2392 0.2630 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1293 0.2591 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1845 0.2598 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1535 0.2571 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1899 0.2584 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1797 0.2604 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1874 0.2596 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1996 0.2607 sec/batch
# Nearest to known: mantle, uga, nmda, europe, shareholding, expellees, aegeus, wasps,
# Nearest to while: secularization, sicilian, affricates, normalized, fused, permeated, predator, rapeseed,
# Nearest to who: wife, fellow, executor, indeed, gifts, hopper, mickiewicz, homeless,
# Nearest to with: csf, deem, deism, skewed, gallons, amply, mashed, anabolic,
# Nearest to an: maskable, mileva, halicarnassus, novellae, defining, colonial, ep, valuables,
# Nearest to into: orchards, gt, rigid, iterations, tung, cambrian, vdp, jaguar,
# Nearest to people: participants, bcd, argues, microarchitecture, replicates, smoothness, cervical, proximity,
# Nearest to d: actaeon, statesman, contemptuous, explorer, eroticism, g, croatian, composer,
# Nearest to creation: treatise, amigas, empiricists, plummet, carolinas, svg, saturation, better,
# Nearest to consists: climates, glacial, orthogonality, summers, between, medical, predominate, livery,
# Nearest to orthodox: toleration, apostolic, patriarch, persecuted, oriental, theological, iv, does,
# Nearest to governor: approval, cabinet, dredged, selects, stroessner, tories, advisor, council,
# Nearest to writers: philosophers, essayists, theology, quicksilver, alumni, grateful, deaths, xenophanes,
# Nearest to rise: polisario, biasing, sled, incidents, foote, brisingamen, foxtrot, polluted,
# Nearest to paris: gai, pollard, venona, parma, fart, creations, tauris, hampshire,
# Nearest to heavy: fire, aliases, homeported, bonifacio, ennio, balochis, codebase, meatballwiki,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1886 0.2488 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2032 0.2590 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1768 0.2610 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1671 0.2612 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1846 0.2467 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1889 0.2609 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2064 0.2581 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1877 0.2549 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1473 0.2600 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1657 0.2591 sec/batch
# Nearest to known: uga, mantle, nmda, shareholding, europe, aegeus, wasps, unquestioning,
# Nearest to while: secularization, affricates, sicilian, normalized, permeated, fused, vcs, terminates,
# Nearest to who: wife, indeed, executor, sardar, rentenmark, fellow, pirated, mickiewicz,
# Nearest to with: csf, deem, deism, skewed, anabolic, batumi, wingers, teetotalers,
# Nearest to an: maskable, novellae, halicarnassus, mileva, ep, colonial, vehicular, defining,
# Nearest to into: orchards, gt, iterations, rigid, tung, cambrian, ecuador, spar,
# Nearest to people: bcd, participants, microarchitecture, disabilities, proximity, argues, replicates, coloureds,
# Nearest to d: actaeon, statesman, composer, eroticism, contemptuous, explorer, one, g,
# Nearest to creation: treatise, amigas, empiricists, plummet, better, saturation, carolinas, incised,
# Nearest to consists: climates, glacial, orthogonality, voivodship, summers, predominate, medical, representatives,
# Nearest to orthodox: toleration, patriarch, oriental, apostolic, persecuted, churches, chalcedonian, constantinople,
# Nearest to governor: approval, cabinet, selects, stroessner, dredged, tories, council, advisor,
# Nearest to writers: philosophers, essayists, quicksilver, alumni, theology, deaths, fiction, grateful,
# Nearest to rise: polisario, incidents, sled, biasing, brisingamen, polluted, denverites, foote,
# Nearest to paris: gai, parma, creations, pollard, tauris, venona, fart, hampshire,
# Nearest to heavy: fire, aliases, homeported, bonifacio, ennio, withdraws, dockyard, meatballwiki,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2195 0.2618 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1645 0.2610 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1929 0.2583 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1632 0.2613 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1437 0.2598 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1198 0.2623 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1841 0.2553 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1199 0.2633 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1886 0.2619 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2395 0.2549 sec/batch
# Nearest to known: uga, mantle, europe, shareholding, unquestioning, aegeus, anatomically, expellees,
# Nearest to while: secularization, sicilian, affricates, permeated, terminates, normalized, quashed, staunchest,
# Nearest to who: sardar, wife, executor, mickiewicz, fellow, homeless, metered, ic,
# Nearest to with: batumi, csf, wingers, skewed, new, deem, teetotalers, amply,
# Nearest to an: colonial, unanimous, halicarnassus, novellae, mileva, ep, fianna, menlo,
# Nearest to into: orchards, tung, ganges, ecuador, gt, recapture, vpns, iterations,
# Nearest to people: bouchard, coloureds, participants, bcd, argues, egan, creature, zinoviev,
# Nearest to d: statesman, actaeon, composer, one, eroticism, croatian, nikolaevich, antoine,
# Nearest to creation: treatise, empiricists, amigas, plummet, carolinas, fiorina, svg, incised,
# Nearest to consists: climates, glacial, voivodship, orthogonality, rupert, predominate, medical, representatives,
# Nearest to orthodox: toleration, patriarch, oriental, apostolic, churches, persecuted, chalcedonian, oscillatory,
# Nearest to governor: approval, selects, dredged, cabinet, tories, advisor, stroessner, council,
# Nearest to writers: philosophers, essayists, alumni, deaths, quicksilver, fiction, theology, lash,
# Nearest to rise: polisario, incidents, sled, invasion, polluted, hungary, mossad, woe,
# Nearest to paris: parma, gai, venona, creations, pollard, tauris, prevenient, fart,
# Nearest to heavy: fire, bonifacio, ennio, homeported, balochis, boomerang, withdraws, aliases,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2359 0.2621 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1212 0.2593 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1417 0.2591 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1405 0.2612 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0702 0.2606 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1181 0.2608 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1702 0.2566 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1328 0.2599 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.2205 0.0524 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1286 0.2495 sec/batch
# Nearest to known: uga, unquestioning, mantle, europe, shareholding, dyes, greatly, communicating,
# Nearest to while: secularization, sicilian, affricates, permeated, quashed, resentment, heresiologists, normalized,
# Nearest to who: homeless, fellow, blows, mickiewicz, sardar, ic, freeing, pirated,
# Nearest to with: deem, csf, batumi, skewed, gallons, wingers, new, deism,
# Nearest to an: colonial, mileva, qualifiers, unanimous, nine, ize, novellae, halicarnassus,
# Nearest to into: orchards, tung, ecuador, gt, spar, ganges, jaguar, iterations,
# Nearest to people: coloureds, proximity, bouchard, zinoviev, bcd, orientation, argues, participants,
# Nearest to d: actaeon, statesman, composer, croatian, one, eroticism, nikolaevich, henri,
# Nearest to creation: treatise, empiricists, amigas, fiorina, svg, plummet, metallocenes, carolinas,
# Nearest to consists: climates, glacial, voivodship, orthogonality, predominate, rupert, livery, summers,
# Nearest to orthodox: toleration, patriarch, apostolic, oriental, chalcedonian, oscillatory, persecuted, churches,
# Nearest to governor: approval, dredged, selects, cabinet, tories, council, cardinal, coalesce,
# Nearest to writers: essayists, philosophers, deaths, quicksilver, alumni, fiction, polemical, gwen,
# Nearest to rise: polisario, polluted, sled, invasion, denverites, incidents, brisingamen, winds,
# Nearest to paris: parma, gai, tauris, venona, creations, fart, christiern, le,
# Nearest to heavy: fire, ennio, homeported, balochis, bonifacio, boomerang, lehrer, withdraws,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0903 0.2662 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0497 0.2678 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0938 0.2627 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0649 0.2565 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0532 0.2649 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0241 0.2545 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0944 0.2529 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0639 0.2610 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1347 0.2566 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0138 0.2580 sec/batch
# Nearest to known: uga, shareholding, unquestioning, europe, mantle, greatly, century, wasps,
# Nearest to while: secularization, sicilian, affricates, quashed, normalized, punters, resentment, permeated,
# Nearest to who: homeless, fellow, orwellian, sardar, nihilo, mickiewicz, indeed, pirated,
# Nearest to with: deem, csf, anabolic, skewed, deism, gallons, amply, new,
# Nearest to an: colonial, ize, maskable, valuables, mileva, novellae, qualifiers, unanimous,
# Nearest to into: orchards, ecuador, tung, ganges, gt, vdp, vpns, iterations,
# Nearest to people: coloureds, bouchard, bcd, argues, creature, proximity, egan, wycliffe,
# Nearest to d: actaeon, statesman, composer, contemptuous, croatian, eroticism, g, luigi,
# Nearest to creation: treatise, empiricists, amigas, fiorina, plummet, svg, lois, incised,
# Nearest to consists: climates, glacial, voivodship, predominate, orthogonality, livery, representatives, districts,
# Nearest to orthodox: toleration, patriarch, oriental, chalcedonian, churches, apostolic, oscillatory, persecuted,
# Nearest to governor: approval, selects, dredged, cabinet, tories, council, coalesce, stroessner,
# Nearest to writers: philosophers, essayists, deaths, alumni, quicksilver, polemical, fiction, gwen,
# Nearest to rise: polisario, woe, denverites, brisingamen, incidents, polluted, invasion, hungary,
# Nearest to paris: parma, gai, tauris, creations, venona, fart, christiern, pollard,
# Nearest to heavy: fire, ennio, boomerang, balochis, homeported, bonifacio, withdraws, counterfeit,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0202 0.2636 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0505 0.2592 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0340 0.2578 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0506 0.2561 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0774 0.2576 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0486 0.2613 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0645 0.2593 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0946 0.2586 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0712 0.2591 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0656 0.2602 sec/batch
# Nearest to known: uga, soprano, dyes, unquestioning, greatly, mantle, nmda, wasps,
# Nearest to while: secularization, sicilian, affricates, normalized, punters, snowstorms, fused, curbing,
# Nearest to who: blows, bears, homeless, trusted, fellow, sardar, wife, indeed,
# Nearest to with: csf, gallons, deem, amply, the, new, deism, skewed,
# Nearest to an: ize, colonial, a, maskable, lipschitz, cetacea, valuables, illustrating,
# Nearest to into: iterations, orchards, ecuador, tung, gt, vpns, vdp, rigid,
# Nearest to people: coloureds, bouchard, creature, bcd, addicts, disabilities, argues, microarchitecture,
# Nearest to d: actaeon, statesman, composer, eroticism, contemptuous, g, finely, croatian,
# Nearest to creation: treatise, empiricists, amigas, fiorina, lois, outgrowth, svg, arthur,
# Nearest to consists: representatives, voivodship, climates, glacial, each, seats, orthogonality, predominate,
# Nearest to orthodox: toleration, patriarch, oriental, chalcedonian, apostolic, churches, oscillatory, persecuted,
# Nearest to governor: approval, selects, dredged, cabinet, tories, council, coalesce, stroessner,
# Nearest to writers: essayists, philosophers, deaths, alumni, fiction, polemical, quicksilver, literature,
# Nearest to rise: polisario, denverites, polluted, feces, incidents, woe, winds, biasing,
# Nearest to paris: tauris, parma, gai, creations, venona, fart, le, christiern,
# Nearest to heavy: fire, ennio, boomerang, balochis, bonifacio, counterfeit, humvee, homeported,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0598 0.2607 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0730 0.2590 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0896 0.2567 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0642 0.2574 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0433 0.2546 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0622 0.2617 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0812 0.2570 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0554 0.2643 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0786 0.2579 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0887 0.2571 sec/batch
# Nearest to known: uga, unquestioning, soprano, century, greatly, mantle, dyes, wasps,
# Nearest to while: secularization, sicilian, affricates, normalized, permeated, initially, fused, curbing,
# Nearest to who: homeless, sardar, nihilo, ic, trusted, fellow, blows, betrays,
# Nearest to with: the, new, csf, amply, gallons, deem, wingers, deism,
# Nearest to an: colonial, ize, unanimous, lipschitz, valuables, halicarnassus, in, lonsdale,
# Nearest to into: tung, iterations, recapture, ganges, ecuador, orchards, vpns, tried,
# Nearest to people: bouchard, coloureds, orientation, disabilities, proximity, microarchitecture, bcd, creature,
# Nearest to d: actaeon, statesman, contemptuous, eroticism, finely, composer, g, nikolaevich,
# Nearest to creation: treatise, empiricists, amigas, fiorina, outgrowth, plummet, lois, arthur,
# Nearest to consists: voivodship, representatives, rupert, climates, each, glacial, predominate, orthogonality,
# Nearest to orthodox: toleration, patriarch, oriental, chalcedonian, apostolic, oscillatory, does, churches,
# Nearest to governor: approval, selects, cabinet, dredged, tories, council, exercised, presiding,
# Nearest to writers: essayists, philosophers, deaths, fiction, quicksilver, alumni, polemical, literature,
# Nearest to rise: polisario, denverites, hungary, woe, incidents, lindo, brisingamen, invasion,
# Nearest to paris: le, parma, gai, creations, tauris, venona, dans, fart,
# Nearest to heavy: ennio, boomerang, balochis, counterfeit, humvee, bonifacio, fire, lehrer,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0824 0.2612 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0112 0.2593 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0460 0.2579 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0748 0.2597 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1078 0.2567 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1271 0.2631 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1472 0.2531 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0572 0.2608 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0139 0.2569 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0397 0.2545 sec/batch
# Nearest to known: uga, obtainable, unquestioning, century, greatly, dyes, mantle, soprano,
# Nearest to while: sicilian, secularization, affricates, curbing, punters, snowstorms, gluck, quashed,
# Nearest to who: homeless, fellow, ic, sardar, mickiewicz, blows, trusted, pirated,
# Nearest to with: csf, the, new, gallons, deem, amply, skewed, bait,
# Nearest to an: colonial, ize, lipschitz, mileva, kx, westphalian, novellae, unanimous,
# Nearest to into: vpns, recapture, iterations, tung, tried, ecuador, ganges, orchards,
# Nearest to people: bouchard, coloureds, proximity, orientation, dependency, disabilities, addicts, cervical,
# Nearest to d: actaeon, statesman, composer, contemptuous, nikolaevich, croatian, eroticism, g,
# Nearest to creation: treatise, empiricists, fiorina, amigas, batasuna, arthur, lois, plummet,
# Nearest to consists: representatives, each, rupert, voivodship, climates, seats, orthogonality, livery,
# Nearest to orthodox: toleration, patriarch, oriental, chalcedonian, oscillatory, densely, apostolic, abrogated,
# Nearest to governor: approval, selects, dredged, cabinet, tories, cardinal, council, comarca,
# Nearest to writers: essayists, philosophers, deaths, alumni, fiction, novelists, polemical, quicksilver,
# Nearest to rise: polisario, hungary, denverites, polluted, invasion, lindo, prosperity, woe,
# Nearest to paris: le, parma, tauris, venona, gai, fart, dans, creations,
# Nearest to heavy: ennio, boomerang, counterfeit, balochis, bonifacio, lehrer, fire, homeported,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9966 0.2678 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0104 0.2617 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0216 0.2595 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0352 0.2625 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0802 0.2581 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0262 0.2415 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0197 0.2588 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9791 0.2622 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0226 0.2616 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9962 0.2626 sec/batch
# Nearest to known: uga, century, unquestioning, greatly, soprano, shareholding, dyes, obtainable,
# Nearest to while: secularization, sicilian, affricates, initially, permeated, resulted, physiocrats, heresiologists,
# Nearest to who: homeless, fellow, betrays, sardar, trusted, mickiewicz, wife, potions,
# Nearest to with: gallons, csf, new, skewed, the, amply, deem, anabolic,
# Nearest to an: colonial, ize, westphalian, halicarnassus, duby, semi, qualifiers, unanimous,
# Nearest to into: iterations, recapture, ecuador, vpns, ganges, tung, orchards, spar,
# Nearest to people: coloureds, bouchard, proximity, dependency, cervical, pakistan, addicts, orientation,
# Nearest to d: actaeon, composer, statesman, croatian, nikolaevich, eroticism, journalist, contemptuous,
# Nearest to creation: treatise, empiricists, amigas, lois, fiorina, arthur, plummet, outgrowth,
# Nearest to consists: each, representatives, voivodship, passers, rupert, glacial, climates, numbered,
# Nearest to orthodox: toleration, patriarch, oriental, chalcedonian, apostolic, abrogated, oscillatory, densely,
# Nearest to governor: selects, approval, dredged, tories, cabinet, comarca, cardinal, stroessner,
# Nearest to writers: essayists, philosophers, deaths, fiction, alumni, polemical, novelists, readily,
# Nearest to rise: polisario, hungary, denverites, woe, prosperity, winds, lindo, brisingamen,
# Nearest to paris: le, dans, venona, parma, tauris, creations, gai, tous,
# Nearest to heavy: ennio, boomerang, counterfeit, bonifacio, balochis, lehrer, humvee, homeported,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0086 0.2694 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9235 0.2619 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0207 0.2538 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0006 0.2647 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9985 0.2634 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9766 0.2538 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9145 0.2648 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9748 0.2611 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9350 0.2565 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9947 0.2567 sec/batch
# Nearest to known: uga, century, soprano, obtainable, shareholding, dyes, central, numbered,
# Nearest to while: sicilian, secularization, affricates, aerobic, normalized, punters, initially, snowstorms,
# Nearest to who: homeless, fellow, sardar, unmop, betrays, bears, potions, blows,
# Nearest to with: the, csf, new, gallons, skewed, such, amply, bait,
# Nearest to an: colonial, a, ize, in, westphalian, hypoxic, qualifiers, valuables,
# Nearest to into: iterations, vpns, orchards, ecuador, genomes, recapture, spar, ganges,
# Nearest to people: coloureds, bouchard, proximity, disabilities, orientation, hiv, desoto, cervical,
# Nearest to d: actaeon, finely, contemptuous, favours, rup, croatian, eroticism, composer,
# Nearest to creation: empiricists, treatise, lois, amigas, fiorina, outgrowth, arthur, batasuna,
# Nearest to consists: each, representatives, voivodship, climates, numbered, passers, seats, districts,
# Nearest to orthodox: toleration, patriarch, chalcedonian, oriental, apostolic, abrogated, hsk, churches,
# Nearest to governor: selects, dredged, approval, comarca, tories, cabinet, stroessner, council,
# Nearest to writers: essayists, philosophers, deaths, fiction, alumni, novelists, polemical, readily,
# Nearest to rise: polisario, denverites, hungary, lindo, woe, polluted, pseudonyms, mediate,
# Nearest to paris: dans, le, venona, tauris, creations, parma, gai, fart,
# Nearest to heavy: ennio, bonifacio, counterfeit, boomerang, humvee, engagements, balochis, fire,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0104 0.2702 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0196 0.2621 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9600 0.2465 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0191 0.2593 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0270 0.2614 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9396 0.2602 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9904 0.2586 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9934 0.2623 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9860 0.2562 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0082 0.2580 sec/batch
# Nearest to known: uga, century, soprano, kassites, obtainable, numbered, dyes, unquestioning,
# Nearest to while: secularization, sicilian, normalized, affricates, aerobic, initially, resulted, punters,
# Nearest to who: homeless, fellow, betrays, sardar, bears, skid, nihilo, potions,
# Nearest to with: the, such, new, csf, skewed, candidiasis, bros, amongst,
# Nearest to an: colonial, a, ize, in, lipschitz, is, valuables, semi,
# Nearest to into: iterations, vpns, ecuador, recapture, genomes, tried, orchards, tung,
# Nearest to people: coloureds, bouchard, addicts, proximity, disabilities, belzec, cervical, piping,
# Nearest to d: actaeon, composer, eroticism, nikolaevich, statesman, croatian, luigi, udall,
# Nearest to creation: empiricists, treatise, lois, amigas, fiorina, outgrowth, societies, fundamentalisms,
# Nearest to consists: each, representatives, seats, numbered, passers, voivodship, steepest, associate,
# Nearest to orthodox: patriarch, toleration, oriental, chalcedonian, apostolic, churches, orthodoxy, patriarchate,
# Nearest to governor: dredged, selects, approval, comarca, tories, stroessner, cardinal, coalesce,
# Nearest to writers: essayists, philosophers, deaths, fiction, alumni, novelists, polemical, quicksilver,
# Nearest to rise: polisario, lindo, denverites, hungary, woe, pseudonyms, geotechnical, cryptosystems,
# Nearest to paris: dans, le, tauris, venona, parma, gai, creations, tous,
# Nearest to heavy: bonifacio, ennio, counterfeit, humvee, boomerang, balochis, engagements, withdraws,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0073 0.2618 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9622 0.2564 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9771 0.2602 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0005 0.2548 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0106 0.2608 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9736 0.2571 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9704 0.2599 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9532 0.2606 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9845 0.2562 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0002 0.2580 sec/batch
# Nearest to known: uga, century, kassites, soprano, culture, central, obtainable, greatly,
# Nearest to while: secularization, sicilian, affricates, resulted, initially, migrating, physiocrats, punters,
# Nearest to who: homeless, dogmas, fellow, methodius, sardar, nihilo, hadith, nemesis,
# Nearest to with: the, new, csf, skewed, such, namibia, amongst, which,
# Nearest to an: colonial, a, ize, in, unanimous, lipschitz, presaging, the,
# Nearest to into: iterations, recapture, ecuador, vpns, tung, genomes, ganges, integrated,
# ...
# Nearest to into: iterations, from, breaks, genomes, program, remainder, incompetent, vegetable,
# Nearest to people: births, bouchard, alumni, killed, coloureds, tabbed, wycliffe, addicts,
# Nearest to d: favours, argyle, vian, gale, heim, g, lox, nikolaevich,
# Nearest to creation: treatise, empiricists, lois, framework, fundamentalisms, albertus, batasuna, similarities,
# Nearest to consists: passers, each, numbered, determines, majilis, voivodship, consist, guatemalan,
# Nearest to orthodox: patriarch, toleration, oriental, countercult, lyceum, orthodoxy, jewish, unpatriotic,
# Nearest to governor: selects, dredged, comarca, coalesce, adjacency, mandamus, tories, appointing,
# Nearest to writers: essayists, deaths, philosophers, novelists, fiction, births, autodidacts, alumni,
# Nearest to rise: documented, hungary, denverites, prosperity, lindo, floodgates, foxtrot, meteorologists,
# Nearest to paris: le, dans, lachaise, france, cimeti, petits, les, tauris,
# Nearest to heavy: vili, humvee, bathed, lehrer, fire, boomerang, toured, ennio,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8295 0.2404 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8732 0.2556 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8512 0.2463 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8250 0.2419 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8813 0.2377 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8650 0.2279 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8656 0.2411 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8250 0.2436 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8929 0.2403 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8707 0.2535 sec/batch
# Nearest to known: central, uga, the, century, other, singlet, were, numbered,
# Nearest to while: sicilian, in, generally, burgh, migrating, secularization, alertness, other,
# Nearest to who: fellow, untaet, sinning, them, homeless, sardar, nowadays, unmop,
# Nearest to with: the, and, which, in, both, as, to, on,
# Nearest to an: a, in, the, for, is, of, as, to,
# Nearest to into: from, breaks, iterations, genomes, pollux, remainder, recapture, plains,
# Nearest to people: births, bouchard, alumni, killed, coloureds, humanitarians, interpreted, tabbed,
# Nearest to d: favours, vian, argyle, gale, heim, g, nikolaevich, ces,
# Nearest to creation: treatise, lois, framework, empiricists, fundamentalisms, batasuna, revulsion, albertus,
# Nearest to consists: passers, each, majilis, voivodship, consist, determines, numbered, steepest,
# Nearest to orthodox: patriarch, oriental, countercult, certain, orthodoxy, toleration, constantinople, lyceum,
# Nearest to governor: selects, comarca, dredged, adjacency, appointing, mandamus, tories, coalesce,
# Nearest to writers: essayists, deaths, philosophers, fiction, novelists, autodidacts, births, inventors,
# Nearest to rise: prosperity, hungary, documented, denverites, floodgates, lindo, meteorologists, polisario,
# Nearest to paris: dans, le, lachaise, france, petits, cimeti, rature, seine,
# Nearest to heavy: humvee, bathed, vili, toured, lehrer, bonifacio, swamped, boomerang,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8540 0.3071 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8526 0.2661 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8559 0.2781 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8138 0.3185 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9002 0.2608 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8343 0.2656 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9632 0.2536 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8645 0.2616 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9025 0.2458 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8057 0.2408 sec/batch
# Nearest to known: central, century, uga, the, other, singlet, were, numbered,
# Nearest to while: sicilian, in, generally, alertness, and, initially, burgh, migrating,
# Nearest to who: untaet, fellow, homeless, unmop, them, nowadays, sardar, sinning,
# Nearest to with: the, and, to, both, as, which, in, on,
# Nearest to an: a, in, the, to, for, of, as, is,
# Nearest to into: from, iterations, breaks, pollux, genomes, remainder, plains, recapture,
# Nearest to people: births, alumni, bouchard, humanitarians, killed, coloureds, writers, proximity,
# Nearest to d: favours, vian, composer, heim, nikolaevich, g, brancusi, croatian,
# Nearest to creation: treatise, framework, lois, fundamentalisms, empiricists, batasuna, revulsion, huacaya,
# Nearest to consists: each, passers, voivodship, majilis, steepest, numbered, guatemalan, of,
# Nearest to orthodox: patriarch, countercult, oriental, lyceum, jewish, segmental, unpatriotic, certain,
# Nearest to governor: selects, dredged, comarca, adjacency, coalesce, joinville, mandamus, liveries,
# Nearest to writers: essayists, deaths, philosophers, novelists, fiction, autodidacts, births, alumni,
# Nearest to rise: prosperity, hungary, documented, denverites, floodgates, lindo, meteorologists, polisario,
# Nearest to paris: lachaise, le, dans, france, cimeti, seine, petits, tauris,
# Nearest to heavy: toured, bathed, lehrer, swamped, vili, bonifacio, humvee, boomerang,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7879 0.2527 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8793 0.2547 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8013 0.2860 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8361 0.2599 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8268 0.2451 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8459 0.2612 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9159 0.1460 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8127 0.2512 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8333 0.2492 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8222 0.2704 sec/batch
# Nearest to known: uga, central, century, the, were, singlet, popular, other,
# Nearest to while: sicilian, in, generally, and, alertness, burgh, initially, other,
# Nearest to who: untaet, fellow, them, demigod, homeless, of, unmop, sardar,
# Nearest to with: the, and, which, as, to, in, of, for,
# Nearest to an: a, in, the, to, is, for, of, as,
# Nearest to into: from, iterations, breaks, pollux, plains, genomes, remainder, incompetent,
# Nearest to people: births, alumni, humanitarians, bouchard, coloureds, killed, writers, tabbed,
# Nearest to d: one, favours, vian, composer, politician, heim, croatian, brancusi,
# Nearest to creation: treatise, framework, lois, fundamentalisms, empiricists, batasuna, revulsion, huacaya,
# Nearest to consists: each, passers, steepest, voivodship, majilis, determines, numbered, guatemalan,
# Nearest to orthodox: patriarch, lyceum, countercult, segmental, postcards, unpatriotic, oriental, jewish,
# Nearest to governor: selects, dredged, comarca, adjacency, joinville, coalesce, mandamus, approval,
# Nearest to writers: essayists, deaths, philosophers, novelists, fiction, autodidacts, alumni, births,
# Nearest to rise: documented, hungary, prosperity, denverites, meteorologists, floodgates, lindo, foxtrot,
# Nearest to paris: lachaise, dans, le, france, seine, cimeti, petits, rature,
# Nearest to heavy: toured, bathed, vili, lehrer, swamped, ennio, sawed, humvee,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8219 0.2581 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8232 0.2512 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8386 0.2448 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7818 0.2369 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8419 0.2378 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8480 0.2310 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8780 0.2374 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7569 0.2523 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8133 0.2874 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7894 0.2720 sec/batch
# Nearest to known: the, uga, central, singlet, other, are, century, well,
# Nearest to while: sicilian, generally, in, and, undifferentiated, other, alertness, burgh,
# Nearest to who: untaet, fellow, them, homeless, unmop, demigod, weu, likely,
# Nearest to with: the, and, in, as, to, which, of, both,
# Nearest to an: a, in, the, to, is, of, as, this,
# Nearest to into: from, iterations, breaks, genomes, plains, which, remainder, process,
# Nearest to people: births, bouchard, alumni, humanitarians, coloureds, killed, deaths, article,
# Nearest to d: favours, vian, heim, g, ces, brancusi, gale, argyle,
# Nearest to creation: treatise, framework, fundamentalisms, lois, revulsion, batasuna, empiricists, huacaya,
# Nearest to consists: each, of, passers, majilis, guatemalan, voivodship, numbered, consist,
# Nearest to orthodox: patriarch, countercult, segmental, lyceum, oriental, unpatriotic, postcards, reestablished,
# Nearest to governor: selects, dredged, comarca, adjacency, coalesce, mandamus, joinville, appointing,
# Nearest to writers: essayists, deaths, novelists, philosophers, fiction, autodidacts, alumni, births,
# Nearest to rise: prosperity, hungary, documented, denverites, foxtrot, lindo, meteorologists, floodgates,
# Nearest to paris: dans, lachaise, le, france, petits, cimeti, docteur, rature,
# Nearest to heavy: vili, bathed, sawed, toured, swamped, humvee, lehrer, fire,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7706 0.2643 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8199 0.2460 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8550 0.2391 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8441 0.2514 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8085 0.2621 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9000 0.2370 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8529 0.2359 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8166 0.2506 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7999 0.2439 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8398 0.2553 sec/batch
# Nearest to known: uga, central, other, popular, the, singlet, greatly, use,
# Nearest to while: in, sicilian, generally, and, other, undifferentiated, alertness, to,
# Nearest to who: untaet, fellow, homeless, them, demigod, nowadays, likely, sardar,
# Nearest to with: the, and, of, to, which, as, in, on,
# Nearest to an: a, in, the, to, is, for, of, which,
# Nearest to into: from, breaks, iterations, remainder, genomes, incompetent, which, then,
# Nearest to people: births, bouchard, alumni, coloureds, interpreted, humanitarians, article, killed,
# Nearest to d: favours, brancusi, g, ces, argyle, heim, gale, vian,
# Nearest to creation: treatise, framework, lois, fundamentalisms, revulsion, empiricists, huacaya, created,
# Nearest to consists: each, passers, guatemalan, majilis, consist, numbered, determines, voivodship,
# Nearest to orthodox: patriarch, countercult, oriental, certain, coal, unpatriotic, segmental, reestablished,
# Nearest to governor: selects, dredged, adjacency, comarca, mandamus, coalesce, browsers, sandberg,
# Nearest to writers: essayists, deaths, philosophers, novelists, fiction, autodidacts, alumni, births,
# Nearest to rise: prosperity, documented, hungary, denverites, foxtrot, lindo, meteorologists, floodgates,
# Nearest to paris: dans, lachaise, le, france, seine, rature, docteur, petits,
# Nearest to heavy: bathed, vili, sawed, toured, humvee, lehrer, swamped, fire,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8901 0.3143 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8133 0.2672 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8177 0.2351 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8440 0.2343 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8676 0.2352 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8442 0.2783 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8361 0.2563 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8722 0.2625 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7983 0.2673 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8062 0.2368 sec/batch
# Nearest to known: central, uga, other, century, singlet, popular, were, also,
# Nearest to while: in, sicilian, generally, and, other, alertness, to, initially,
# Nearest to who: untaet, fellow, homeless, them, nowadays, demigod, likely, populate,
# Nearest to with: the, and, of, to, which, as, in, both,
# Nearest to an: a, the, in, for, to, of, is, which,
# Nearest to into: from, iterations, genomes, breaks, which, then, pollux, remainder,
# Nearest to people: births, bouchard, article, interpreted, humanitarians, alumni, coloureds, hannah,
# Nearest to d: favours, ces, g, heim, brancusi, gale, argyle, loire,
# Nearest to creation: treatise, framework, lois, fundamentalisms, revulsion, created, huacaya, batasuna,
# Nearest to consists: each, passers, guatemalan, majilis, of, consist, voivodship, steepest,
# Nearest to orthodox: patriarch, countercult, oriental, certain, unpatriotic, reestablished, segmental, disagreed,
# Nearest to governor: selects, dredged, comarca, adjacency, appointing, mandamus, coalesce, administrator,
# Nearest to writers: essayists, deaths, fiction, novelists, philosophers, births, autodidacts, alumni,
# Nearest to rise: documented, prosperity, hungary, denverites, foxtrot, lindo, meteorologists, floodgates,
# Nearest to paris: dans, lachaise, le, france, idols, docteur, rature, cimeti,
# Nearest to heavy: bathed, vili, toured, lehrer, sawed, swamped, ennio, humvee,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8652 0.2916 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8200 0.3056 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9338 0.2992 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9049 0.2635 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8909 0.2698 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8394 0.2544 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7596 0.2323 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8506 0.2374 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7539 0.2512 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8655 0.2444 sec/batch
# Nearest to known: central, other, popular, singlet, uga, use, the, were,
# Nearest to while: in, sicilian, generally, and, to, alertness, other, initially,
# Nearest to who: untaet, fellow, them, homeless, unmop, demigod, sardar, sinning,
# Nearest to with: the, and, to, on, as, of, in, which,
# Nearest to an: a, the, in, for, to, of, is, by,
# Nearest to into: from, plains, which, breaks, genomes, iterations, the, pollux,
# Nearest to people: births, alumni, bouchard, humanitarians, deaths, article, coloureds, interpreted,
# Nearest to d: one, composer, favours, nikolaevich, brancusi, heim, vian, gale,
# Nearest to creation: treatise, lois, fundamentalisms, framework, revulsion, created, huacaya, empiricists,
# Nearest to consists: each, passers, majilis, consist, guatemalan, voivodship, determines, of,
# Nearest to orthodox: patriarch, countercult, unpatriotic, segmental, favorable, dmitry, oriental, microtonal,
# Nearest to governor: selects, dredged, comarca, adjacency, joinville, liveries, browsers, coalesce,
# Nearest to writers: essayists, deaths, novelists, fiction, philosophers, births, autodidacts, alumni,
# Nearest to rise: prosperity, denverites, hungary, documented, floodgates, lindo, meteorologists, practically,
# Nearest to paris: lachaise, dans, le, france, seine, rature, briar, cimeti,
# Nearest to heavy: toured, bathed, lehrer, sawed, vili, swamped, ennio, fire,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8005 0.2582 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8400 0.2604 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
